# %%
# !wget -O "airbnb-listings.csv" "https://public.opendatasoft.com/explore/dataset/airbnb-listings/download/?format=csv&disjunctive.host_verifications=true&disjunctive.amenities=true&disjunctive.features=true&refine.country=Spain&q=Madrid&timezone=Europe/London&use_labels_for_header=true&csv_separator=%3B"
# Out:
# --2024-03-03 17:02:53--  https://public.opendatasoft.com/explore/dataset/airbnb-listings/download/?format=csv&disjunctive.host_verifications=true&disjunctive.amenities=true&disjunctive.features=true&refine.country=Spain&q=Madrid&timezone=Europe/London&use_labels_for_header=true&csv_separator=%3B
# Resolving public.opendatasoft.com (public.opendatasoft.com)... 34.249.199.226, 34.248.20.69
# Connecting to public.opendatasoft.com (public.opendatasoft.com)|34.249.199.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/csv]
# Saving to: ‘airbnb-listings.csv’
#
# airbnb-listings.csv     [         <=>        ]  52.85M  12.6MB/s    in 5.0s
#
# 2024-03-03 17:02:59 (10.6 MB/s) - ‘airbnb-listings.csv’ saved [55414009]

# %%
import cv2
import numpy as np
import pandas as pd
import imageio.v3 as io

from tqdm import tqdm
from typing import Optional, Union

# %%
data = pd.read_csv("airbnb-listings.csv", sep = ';')
data = data.dropna(subset=['Price'])
data
# Out:
#              ID                            Listing Url       Scrape ID  \
# 0      16536728  https://www.airbnb.com/rooms/16536728  20170407214119
# 1      14800288  https://www.airbnb.com/rooms/14800288  20170407214119
# 2      12357427  https://www.airbnb.com/rooms/12357427  20170407214119
# 3       7984552   https://www.airbnb.com/rooms/7984552  20170407214119
# 4      17244421  https://www.airbnb.com/rooms/17244421  20170407214119
# ...         ...                                    ...             ...
# 13996  12185821  https://www.airbnb.com/rooms/12185821  20170407214119
# 13997    799569    https://www.airbnb.com/rooms/799569  20170407214119
# 13998  15542212  https://www.airbnb.com/rooms/15542212  20170407214119
# 13999  14725727  https://www.airbnb.com/rooms/14725727  20170407214119
# 14000  18107783  https://www.airbnb.com/rooms/18107783  20170407214050
#
#       Last Scraped                                    Name  \
# 0       2017-04-08         Ático en el Barrio de Salamanca
# 1       2017-04-08  Salamanca Comfort XI, Friendly Rentals
# 2       2017-04-08        Apt. by the music Conservatory!!
# 3       2017-04-08     Double Room near RealMadrid Stadium
# 4       2017-04-08                        Mid Century Flat
# ...            ...                                     ...
# 13996   2017-04-08     Apartamento completo una habitación
# 13997   2017-04-08      PENTHOUSE/TERRACE, THE CITY CENTER
# 13998   2017-04-08        Cozy & Centric 1BD - Conde Duque
# 13999   2017-04-08               Room near Madrid downtown
# 14000   2017-04-08            Luxury Apt 3BD in Barcelona!
#
#                                                  Summary  \
# 0      Precioso ático en el barrio de Salamanca.  Dos...
# 1      Lugares de interés: Fide, Bienmesabe, Restaura...
# 2      Very bright apartment with 2 bedrooms 1 with p...
# 3      The flat is on the ground floor. There's a com...
# 4      Mi alojamiento es bueno para viajeros de negoc...
# ...                                                  ...
# 13996  Hola! Nuestro apartamento es un lugar acogedor...
# 13997  A charming and beautiful 2 independents bedroo...
# 13998  Calm and confortable apartment. Totally renewe...
# 13999  Highlight Places: Plaza España, Conde Duque Cu...
# 14000  *PLEASE DO NOT INSTANT BOOK before you contact...
#
#                                                    Space  \
# 0                                                    NaN
# 1      Apartamento de nueva construcción (julio 2016)...
# 2                                                    NaN
# 3      Cosy large room for two people with a flat TV ...
# 4                                                    NaN
# ...                                                  ...
# 13996  Muy acogedor, y tenemos un ventanal que da a l...
# 13997  A charming and beautiful 2 bedroom attic The a...
# 13998  Calm and confortable apartment. Totally renewe...
# 13999  It is well located for access to central touri...
# 14000                                                NaN
#
#                                              Description Experiences Offered  \
# 0      Precioso ático en el barrio de Salamanca.  Dos...                none
# 1      Apartamento de nueva construcción (julio 2016)...                none
# 2      Very bright apartment with 2 bedrooms 1 with p...                none
# 3      The flat is on the ground floor. There's a com...                none
# 4      Mi alojamiento es bueno para viajeros de negoc...                none
# ...                                                  ...                 ...
# 13996  Hola! Nuestro apartamento es un lugar acogedor...                none
# 13997  A charming and beautiful 2 independents bedroo...                none
# 13998  Calm and confortable apartment. Totally renewe...                none
# 13999  Highlight Places: Plaza España, Conde Duque Cu...                none
# 14000  *PLEASE DO NOT INSTANT BOOK before you contact...                none
#
#                                    Neighborhood Overview  ...  \
# 0                                                    NaN  ...
# 1      Localizado en el distrito de Salamanca, uno de...  ...
# 2                                                    NaN  ...
# 3      Chamartín is an administrative district of Mad...  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 13996  Es una zona muy céntrica donde tomarte unas ca...  ...
# 13997  Malasaña is considered the Bohemian district M...  ...
# 13998  Conde Duque is a dynamic and central neighborh...  ...
# 13999  The neighborhood has many shops (Zara, El Cort...  ...
# 14000                                                NaN  ...
#
#       Review Scores Communication Review Scores Location Review Scores Value  \
# 0                             NaN                    NaN                 NaN
# 1                             8.0                   10.0                 9.0
# 2                             8.0                    8.0                 8.0
# 3                             NaN                    NaN                 NaN
# 4                             NaN                    NaN                 NaN
# ...                           ...                    ...                 ...
# 13996                         NaN                    NaN                 NaN
# 13997                        10.0                   10.0                 9.0
# 13998                        10.0                   10.0                 9.0
# 13999                        10.0                   10.0                10.0
# 14000                         NaN                    NaN                 NaN
#
#       License Jurisdiction Names Cancellation Policy  \
# 0         NaN                NaN            moderate
# 1         NaN                NaN              strict
# 2         NaN                NaN            flexible
# 3         NaN                NaN            moderate
# 4         NaN                NaN            flexible
# ...       ...                ...                 ...
# 13996     NaN                NaN            flexible
# 13997     NaN                NaN              strict
# 13998     NaN                NaN            flexible
# 13999     NaN                NaN            flexible
# 14000     NaN                NaN            flexible
#
#       Calculated host listings count  Reviews per Month  \
# 0                                  1                NaN
# 1                                145               0.79
# 2                                  1               0.43
# 3                                  2                NaN
# 4                                  1                NaN
# ...                              ...                ...
# 13996                              1                NaN
# 13997                              2               2.40
# 13998                              1               0.94
# 13999                              1               3.28
# 14000                              1                NaN
#
#                                   Geolocation  \
# 0        40.43007580267911,-3.674373225929859
# 1        40.43561324649597,-3.678321445006713
# 2      40.446440723481764,-3.6742595345116214
# 3       40.455167347211834,-3.698099022915008
# 4         40.43988285945364,-3.71737227282086
# ...                                       ...
# 13996  40.397772302001854,-3.6945501615175997
# 13997   40.42579998148187,-3.7040803907189943
# 13998   40.42616571464884,-3.7077944204488813
# 13999     40.43017745149435,-3.71326014626314
# 14000    41.385680758683485,2.175755668563987
#
#                                                 Features
# 0      Host Has Profile Pic,Is Location Exact,Require...
# 1      Host Has Profile Pic,Is Location Exact,Require...
# 2      Host Has Profile Pic,Host Identity Verified,Is...
# 3      Host Is Superhost,Host Has Profile Pic,Is Loca...
# 4      Host Has Profile Pic,Is Location Exact,Require...
# ...                                                  ...
# 13996  Host Has Profile Pic,Host Identity Verified,Is...
# 13997  Host Has Profile Pic,Is Location Exact,Require...
# 13998  Host Has Profile Pic,Host Identity Verified,Is...
# 13999  Host Is Superhost,Host Has Profile Pic,Host Id...
# 14000  Host Has Profile Pic,Host Identity Verified,Is...
#
# [13990 rows x 89 columns]

# %%
# Filtro los datos para la ciudad de madrid
data_madrid = data.loc[data['City'] == 'Madrid']
data_madrid.shape
# Out:
# (13198, 89)

# %%
def download_images(paths: list,
                    canvas: tuple = (224, 224),
                    nb_channels: int = 3,
                    max_imgs: Optional[int] = None
                    ) -> tuple:
  """ Download a list of images from url adresses, converting them to a specific
  canvas size.

  Args:
    paths: Paths or url adresses from which to load images.
    canvas: Desired image width and height.
    nb_channels: Channels in images (1 for B/W, 3 for RGB).
    max_imgs: Upper threshold in the number of images to download.

  Return:
    a tuple of:
      - image values
      - indices within the paths that were successfull.

  """
  n_images = len(paths) if not max_imgs else max_imgs
  images = np.zeros((n_images, canvas[0], canvas[1], nb_channels),
                       dtype=np.uint8)
  downloaded_idxs = []

  for i_img, url in enumerate(tqdm(paths, total=n_images)):
    if i_img >= n_images:
      break
    try:
        img = io.imread(url)
        img = cv2.resize(img, (canvas[0], canvas[1]))
        downloaded_idxs.append(i_img)
        images[i_img] = img
    except (IOError, ValueError) as e:  # Unavailable url / conversion error
        pass
  return images[downloaded_idxs], downloaded_idxs

# %%
images, idxs = download_images(data_madrid['Thumbnail Url'], max_imgs=4000)
images = images.astype("float32") / 255.
images.shape
# Out:
# 100%|██████████| 4000/4000 [18:30<00:00,  3.60it/s]
# (2518, 224, 224, 3)

# %%
filtered_data = data_madrid.iloc[idxs]
filtered_data
# Out:
#             ID                            Listing Url       Scrape ID  \
# 1     14800288  https://www.airbnb.com/rooms/14800288  20170407214119
# 2     12357427  https://www.airbnb.com/rooms/12357427  20170407214119
# 4     17244421  https://www.airbnb.com/rooms/17244421  20170407214119
# 5      5950534   https://www.airbnb.com/rooms/5950534  20170407214119
# 6     15449251  https://www.airbnb.com/rooms/15449251  20170407214119
# ...        ...                                    ...             ...
# 4253  13665156  https://www.airbnb.com/rooms/13665156  20170407214119
# 4255   5781150   https://www.airbnb.com/rooms/5781150  20170407214119
# 4256   9667399   https://www.airbnb.com/rooms/9667399  20170407214119
# 4257  14366176  https://www.airbnb.com/rooms/14366176  20170407214119
# 4258  13517599  https://www.airbnb.com/rooms/13517599  20170407214119
#
#      Last Scraped                                          Name  \
# 1      2017-04-08        Salamanca Comfort XI, Friendly Rentals
# 2      2017-04-08              Apt. by the music Conservatory!!
# 4      2017-04-08                              Mid Century Flat
# 5      2017-04-08                     Beautifull Doble-Bed Room
# 6      2017-04-08     Central Apartment, 2 rooms, Royal Palace.
# ...           ...                                           ...
# 4253   2017-04-08                           Habitación centrica
# 4255   2017-04-08             BARCELÓ, Madrid, Friendly Rentals
# 4256   2017-04-08                 BBC Rooms (Con baño privado )
# 4257   2017-04-08  Apartamento completo céntrico en Madrid Río.
# 4258   2017-04-08                    GRAN CASA CERCA DEL CENTRO
#
#                                                 Summary  \
# 1     Lugares de interés: Fide, Bienmesabe, Restaura...
# 2     Very bright apartment with 2 bedrooms 1 with p...
# 4     Mi alojamiento es bueno para viajeros de negoc...
# 5     Ubicacción is super (Metro Guzman el Bueno 2 m...
# 6     Wonderful apartment in full center of Madrid, ...
# ...                                                 ...
# 4253  Cama doble y una sencilla te nevera terraza ex...
# 4255  A classy, tasteful apartment located in a full...
# 4256  BBC Rooms Airport-Barajas se encuentran a solo...
# 4257  Te va a encantar mi alojamiento por la ubicaci...
# 4258  Casa recién reformada,con el metro y autobús a...
#
#                                                   Space  \
# 1     Apartamento de nueva construcción (julio 2016)...
# 2                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6     Our house is cozy and perfect to rest after a ...
# ...                                                 ...
# 4253                                                NaN
# 4255  A classy, tasteful apartment located in a full...
# 4256                                                NaN
# 4257  Es un apartamento con todas las comodidades, d...
# 4258  Recién reformado,con 3 habitaciones y 2 baños,...
#
#                                             Description Experiences Offered  \
# 1     Apartamento de nueva construcción (julio 2016)...                none
# 2     Very bright apartment with 2 bedrooms 1 with p...                none
# 4     Mi alojamiento es bueno para viajeros de negoc...                none
# 5     Ubicacción is super (Metro Guzman el Bueno 2 m...                none
# 6     Wonderful apartment in full center of Madrid, ...                none
# ...                                                 ...                 ...
# 4253  Cama doble y una sencilla te nevera terraza ex...                none
# 4255  A classy, tasteful apartment located in a full...                none
# 4256  BBC Rooms Airport-Barajas se encuentran a solo...                none
# 4257  Te va a encantar mi alojamiento por la ubicaci...                none
# 4258  Casa recién reformada,con el metro y autobús a...                none
#
#                                   Neighborhood Overview  ...  \
# 1     Localizado en el distrito de Salamanca, uno de...  ...
# 2                                                   NaN  ...
# 4                                                   NaN  ...
# 5                                                   NaN  ...
# 6     The zone possesses shops as well as bars and r...  ...
# ...                                                 ...  ...
# 4253                                                NaN  ...
# 4255  In the district of Chamberí, bordering on Mala...  ...
# 4256                                                NaN  ...
# 4257  Es una zona muy tranquila, (Glorieta de Cadiz)...  ...
# 4258  Es un barrio madrileño que no le falta de nada...  ...
#
#      Review Scores Communication Review Scores Location Review Scores Value  \
# 1                            8.0                   10.0                 9.0
# 2                            8.0                    8.0                 8.0
# 4                            NaN                    NaN                 NaN
# 5                            NaN                    NaN                 NaN
# 6                            8.0                   10.0                 9.0
# ...                          ...                    ...                 ...
# 4253                        10.0                   10.0                10.0
# 4255                        10.0                   10.0                10.0
# 4256                         9.0                    9.0                 9.0
# 4257                        10.0                    9.0                10.0
# 4258                         8.0                    8.0                 8.0
#
#      License Jurisdiction Names Cancellation Policy  \
# 1        NaN                NaN              strict
# 2        NaN                NaN            flexible
# 4        NaN                NaN            flexible
# 5        NaN                NaN            flexible
# 6        NaN                NaN              strict
# ...      ...                ...                 ...
# 4253     NaN                NaN            flexible
# 4255     NaN                NaN              strict
# 4256     NaN                NaN            flexible
# 4257     NaN                NaN              strict
# 4258     NaN                NaN              strict
#
#      Calculated host listings count  Reviews per Month  \
# 1                               145               0.79
# 2                                 1               0.43
# 4                                 1                NaN
# 5                                 1                NaN
# 6                                 1               1.24
# ...                             ...                ...
# 4253                              1               2.14
# 4255                            145               0.21
# 4256                             15               0.79
# 4257                              1               4.94
# 4258                              2               0.97
#
#                                  Geolocation  \
# 1       40.43561324649597,-3.678321445006713
# 2     40.446440723481764,-3.6742595345116214
# 4        40.43988285945364,-3.71737227282086
# 5      40.44584215195265,-3.7098151705375364
# 6       40.42139480164567,-3.717879233014972
# ...                                      ...
# 4253  40.421739616882846,-3.7068096112073823
# 4255    40.42768404558797,-3.699675690056135
# 4256    40.47478950687402,-3.578084058022845
# 4257    40.38596686803499,-3.698539126780821
# 4258    40.39086823351082,-3.654041859576664
#
#                                                Features
# 1     Host Has Profile Pic,Is Location Exact,Require...
# 2     Host Has Profile Pic,Host Identity Verified,Is...
# 4     Host Has Profile Pic,Is Location Exact,Require...
# 5     Host Has Profile Pic,Is Location Exact,Require...
# 6     Host Has Profile Pic,Requires License,Instant ...
# ...                                                 ...
# 4253  Host Is Superhost,Host Has Profile Pic,Require...
# 4255  Host Has Profile Pic,Is Location Exact,Require...
# 4256  Host Has Profile Pic,Host Identity Verified,Is...
# 4257  Host Has Profile Pic,Requires License,Instant ...
# 4258  Host Has Profile Pic,Host Identity Verified,Re...
#
# [2518 rows x 89 columns]

# %%
np.save('images.npy', images)
filtered_data.to_csv('filtered_data.csv', sep=';', index=False)

from google.colab import drive
drive.mount('/content/drive')

# !cp images.npy /content/drive/MyDrive/images_final4000.npy
# !cp filtered_data.csv /content/drive/MyDrive/filtered_data4000.csv
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -lah images* filtered*
# Out:
# -rw-r--r-- 1 root root 9.5M Mar  3 17:22 filtered_data.csv
# -rw-r--r-- 1 root root 1.5G Mar  3 17:22 images.npy

# %%
saved_data = pd.read_csv("/content/drive/MyDrive/filtered_data4000.csv", sep=';')
saved_imgs = np.load("/content/drive/MyDrive/images_final4000.npy")
saved_data.shape, saved_imgs.shape
# Out:
# ((2508, 89), (2508, 224, 224, 3))

# %% [markdown]
# # MODELO DE REGRESION

# %% [markdown]
# ### IMPORTS

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input, concatenate
from tensorflow.keras.optimizers import SGD,Adam
import matplotlib.pyplot as plt
from tensorflow.keras.applications import InceptionV3, Xception, VGG16, VGG19, ResNet50
from tensorflow.keras.applications import imagenet_utils
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras import layers, models
from sklearn.decomposition import PCA

from sklearn.metrics import mean_absolute_error

# %% [markdown]
# DIVIDO EN TRAIN Y TEST

# %%
# separamos de dataset en train, X_train_image, test


(X_train, X_test, X_train_image, X_test_image, y_train, y_test) = train_test_split(saved_data, saved_imgs, saved_data['Price'], test_size=0.2, shuffle=True, random_state=0)


X_train.to_csv('train_filtered_data.csv', sep=';', index=False)
X_test.to_csv('test_filtered_data.csv', sep=';', index=False)

X_train = pd.read_csv('train_filtered_data.csv', sep=';')
X_test = pd.read_csv('test_filtered_data.csv', sep=';')

print('Datos X_train: ', X_train.shape)
print('Datos X_test:  ', X_test.shape)
print('Datos X_train_image: ', X_train_image.shape)
print('Datos X_test_image:  ', X_test_image.shape)
print('Datos y_train: ', y_train.shape)
print('Datos y_test:  ', y_test.shape)
# Out:
# Datos X_train:  (2006, 89)
# Datos X_test:   (502, 89)
# Datos X_train_image:  (2006, 224, 224, 3)
# Datos X_test_image:   (502, 224, 224, 3)
# Datos y_train:  (2006,)
# Datos y_test:   (502,)

# %% [markdown]
# ### PREPROCESADO DE DATOS

# %%
# Borro las columnas que no me interesan despues de un estudio de ellas y la columna Price que es la columna objetivo


X_train = X_train.drop(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary', 'Space', 'Description',
                              'Experiences Offered', 'Neighborhood Overview', 'Notes', 'Transit', 'Access', 'Interaction',
                              'House Rules', 'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url', 'Host ID',
                              'Host URL', 'Host Name', 'Host Since', 'Host Location', 'Host About', 'Host Response Time',
                              'Host Response Rate', 'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
                              'Host Neighbourhood', 'Host Listings Count', 'Host Total Listings Count', 'Host Verifications',
                              'Street', 'Neighbourhood', 'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
                              'Smart Location', 'Country Code', 'Country', 'Amenities', 'Square Feet',
                              'Weekly Price', 'Monthly Price', 'Security Deposit', 'Maximum Nights',
                              'Calendar Updated', 'Has Availability', 'Availability 30', 'Availability 60', 'Availability 90',
                              'Availability 365', 'Calendar last Scraped', 'Number of Reviews', 'First Review', 'Last Review',
                              'Review Scores Accuracy','Review Scores Checkin', 'Review Scores Communication',
                              'Review Scores Value', 'License', 'Jurisdiction Names', 'Calculated host listings count',
                              'Reviews per Month', 'Geolocation', 'Features','Minimum Nights', 'Review Scores Rating', 'Review Scores Cleanliness',
                              'Review Scores Location','Price'],axis=1)


# Codifico las variables categoricas con labelEncoder



le_Neighbourhood_Cleansed = LabelEncoder()
le_Property_Type = LabelEncoder()
le_Room_Type = LabelEncoder()
le_Bed_Type = LabelEncoder()
le_Cancellation_Policy = LabelEncoder()

X_train['Neighbourhood Cleansed'] = le_Neighbourhood_Cleansed.fit_transform(X_train['Neighbourhood Cleansed'])
X_train['Property Type'] = le_Property_Type.fit_transform(X_train['Property Type'])
X_train['Room Type'] = le_Room_Type.fit_transform(X_train['Room Type'])
X_train['Bed Type'] = le_Bed_Type.fit_transform(X_train['Bed Type'])
X_train['Cancellation Policy'] = le_Cancellation_Policy.fit_transform(X_train['Cancellation Policy'])

# Viendo los resultados de registros nan, voy a imputar los valores nan en la variable Cleaning fee como valores 0 porque
# tomo esos valores nan como que no tiene tasa de limpieza
# media o 0 me quedo con la imputacion 0

X_train["Cleaning Fee"].fillna(0, inplace=True)

# Dados los resultados realizados abajo de las medias y las modas, voy a imputar las columnas con las medias

# Imputo a los valores nan con la media obtenida de cada columna

columnas_con_nan = X_train.columns[X_train.isna().any()].tolist()
for i in columnas_con_nan:
    media_columna = X_train[i].mean()
    X_train[i] = X_train[i].fillna(media_columna)



# hago lo mismo que he hecho en los datos train , en los datos de test



X_test = X_test.drop(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary', 'Space', 'Description',
                              'Experiences Offered', 'Neighborhood Overview', 'Notes', 'Transit', 'Access', 'Interaction',
                              'House Rules', 'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url', 'Host ID',
                              'Host URL', 'Host Name', 'Host Since', 'Host Location', 'Host About', 'Host Response Time',
                              'Host Response Rate', 'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
                              'Host Neighbourhood', 'Host Listings Count', 'Host Total Listings Count', 'Host Verifications',
                              'Street', 'Neighbourhood', 'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
                              'Smart Location', 'Country Code', 'Country', 'Amenities', 'Square Feet',
                              'Weekly Price', 'Monthly Price', 'Security Deposit', 'Maximum Nights',
                              'Calendar Updated', 'Has Availability', 'Availability 30', 'Availability 60', 'Availability 90',
                              'Availability 365', 'Calendar last Scraped', 'Number of Reviews', 'First Review', 'Last Review',
                              'Review Scores Accuracy','Review Scores Checkin', 'Review Scores Communication',
                              'Review Scores Value', 'License', 'Jurisdiction Names', 'Calculated host listings count',
                              'Reviews per Month', 'Geolocation', 'Features','Minimum Nights', 'Review Scores Rating', 'Review Scores Cleanliness',
                              'Review Scores Location','Price'],axis=1)


# Codifico las variables categoricas con labelEncoder

le_Neighbourhood_Cleansed = LabelEncoder()
le_Property_Type = LabelEncoder()
le_Room_Type = LabelEncoder()
le_Bed_Type = LabelEncoder()
le_Cancellation_Policy = LabelEncoder()

X_test['Neighbourhood Cleansed'] = le_Neighbourhood_Cleansed.fit_transform(X_test['Neighbourhood Cleansed'])
X_test['Property Type'] = le_Property_Type.fit_transform(X_test['Property Type'])
X_test['Room Type'] = le_Room_Type.fit_transform(X_test['Room Type'])
X_test['Bed Type'] = le_Bed_Type.fit_transform(X_test['Bed Type'])
X_test['Cancellation Policy'] = le_Cancellation_Policy.fit_transform(X_test['Cancellation Policy'])

# voy a imputar los valores nan en la variable Cleaning fee como valores 0

X_test["Cleaning Fee"].fillna(0, inplace=True)

# Dados los resultados realizados abajo de las medias y las modas, voy a imputar las columnas con las medias
# Imputo a los valores nan con la media obtenida de cada columna

columnas_con_nan = X_test.columns[X_test.isna().any()].tolist()
for i in columnas_con_nan:
    media_columna = X_test[i].mean()
    X_test[i] = X_test[i].fillna(media_columna)



print('Datos X_train: ', X_train.shape)
print('Datos X_test:  ', X_test.shape)
print('Datos y_train: ', y_train.shape)
print('Datos y_test:  ', y_test.shape)
# Out:
# Datos X_train:  (2006, 14)
# Datos X_test:   (502, 14)
# Datos y_train:  (2006,)
# Datos y_test:   (502,)

# %% [markdown]
# ESCACALADO

# %%
# ESCALO LOS DATOS DE ENTRADA
np.random.seed(42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ESCALO LOS DATOS Y_TRAIN Y Y_TEST PARA MODELO DE REGRESION
y_train_reg = scaler.fit_transform(y_train.values.reshape(-1, 1)).flatten()
y_test_reg = scaler.fit_transform(y_test.values.reshape(-1, 1)).flatten()

# %% [markdown]
# ### DIVIDO LOS DATOS PARA LOS MODELOS DE REGRESION

# %%
X_train1, X_val,X_train_image1, X_val_image, y_train_reg1, Y_val_reg = train_test_split(X_train,X_train_image, y_train_reg, test_size=0.15, random_state=42)

# %% [markdown]
# ### MODELO DE REGRESION DATOS TABULARES

# %%
# Definir la arquitectura del modelo
num_epochs_R = 150
model_tr = Sequential()
model_tr.add(Dense(64, activation="relu", kernel_initializer="random_uniform", bias_initializer="zeros", input_dim=X_train.shape[1]))
#model_tr.add(Dropout(0.10))
model_tr.add(Dense(64, activation="relu"))
model_tr.add(Dense(1, activation='sigmoid', name = "capa_sigmoide_tabular"))

# Compilar el modelo
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,
    decay_steps=10,
    decay_rate=0.96,
    staircase=True
)
model_tr.compile(loss="mean_absolute_error", optimizer=Adam(learning_rate=lr_schedule), metrics=['mean_squared_error'])


# Entrenar el modelo
print("[INFO]: Entrenando el modelo...")
history = model_tr.fit(X_train1, y_train_reg1, validation_data=(X_val, Y_val_reg), epochs=num_epochs_R, batch_size=64)


# Evaluar el modelo en el conjunto de prueba

mse_train = model_tr.evaluate(X_train1, y_train_reg1, verbose=0)[1]
mse_val = model_tr.evaluate(X_val, Y_val_reg, verbose=0)[1]
print(f'Training MSE: {mse_train}, Validation MSE: {mse_val}')

print("[INFO]: Evaluando red neuronal...")

predictions_esc = model_tr.predict(X_test)
predictions = predictions_esc.reshape(-1, 1)
predictions = scaler.inverse_transform(predictions)

# Calcular el error absoluto medio (MAE) en el conjunto de prueba

y_test_reg_tab = y_test_reg.reshape(-1, 1)
y_test_reg_tab = scaler.inverse_transform(y_test_reg_tab)


# Imprimir resultados


test_error_tab = mean_absolute_error(y_test_reg_tab, predictions)
print(f'Error absoluto en test: {test_error_tab}')

# Muestra gráfica de pérdida
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

print(f'error medio en test: {test_error_tab}')
# Out:
# [INFO]: Entrenando el modelo...
# Epoch 1/150
# 27/27 [==============================] - 1s 9ms/step - loss: 0.8637 - mean_squared_error: 1.2124 - val_loss: 0.8680 - val_mean_squared_error: 1.4173
# Epoch 2/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8515 - mean_squared_error: 1.1882 - val_loss: 0.8569 - val_mean_squared_error: 1.3955
# Epoch 3/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.8397 - mean_squared_error: 1.1652 - val_loss: 0.8457 - val_mean_squared_error: 1.3747
# Epoch 4/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8278 - mean_squared_error: 1.1429 - val_loss: 0.8346 - val_mean_squared_error: 1.3541
# Epoch 5/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8160 - mean_squared_error: 1.1202 - val_loss: 0.8238 - val_mean_squared_error: 1.3344
# Epoch 6/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8045 - mean_squared_error: 1.0992 - val_loss: 0.8131 - val_mean_squared_error: 1.3151
# Epoch 7/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7935 - mean_squared_error: 1.0790 - val_loss: 0.8029 - val_mean_squared_error: 1.2972
# Epoch 8/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7830 - mean_squared_error: 1.0601 - val_loss: 0.7936 - val_mean_squared_error: 1.2808
# Epoch 9/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7733 - mean_squared_error: 1.0431 - val_loss: 0.7850 - val_mean_squared_error: 1.2657
# Epoch 10/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7644 - mean_squared_error: 1.0274 - val_loss: 0.7771 - val_mean_squared_error: 1.2522
# Epoch 11/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7563 - mean_squared_error: 1.0135 - val_loss: 0.7699 - val_mean_squared_error: 1.2400
# Epoch 12/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7490 - mean_squared_error: 1.0010 - val_loss: 0.7635 - val_mean_squared_error: 1.2293
# Epoch 13/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7425 - mean_squared_error: 0.9899 - val_loss: 0.7577 - val_mean_squared_error: 1.2198
# Epoch 14/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7367 - mean_squared_error: 0.9803 - val_loss: 0.7526 - val_mean_squared_error: 1.2115
# Epoch 15/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7317 - mean_squared_error: 0.9719 - val_loss: 0.7482 - val_mean_squared_error: 1.2041
# Epoch 16/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7272 - mean_squared_error: 0.9644 - val_loss: 0.7443 - val_mean_squared_error: 1.1979
# Epoch 17/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7233 - mean_squared_error: 0.9579 - val_loss: 0.7408 - val_mean_squared_error: 1.1921
# Epoch 18/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7198 - mean_squared_error: 0.9521 - val_loss: 0.7378 - val_mean_squared_error: 1.1872
# Epoch 19/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7168 - mean_squared_error: 0.9471 - val_loss: 0.7350 - val_mean_squared_error: 1.1828
# Epoch 20/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7140 - mean_squared_error: 0.9426 - val_loss: 0.7327 - val_mean_squared_error: 1.1790
# Epoch 21/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7116 - mean_squared_error: 0.9387 - val_loss: 0.7306 - val_mean_squared_error: 1.1756
# Epoch 22/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7095 - mean_squared_error: 0.9352 - val_loss: 0.7287 - val_mean_squared_error: 1.1726
# Epoch 23/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7076 - mean_squared_error: 0.9321 - val_loss: 0.7271 - val_mean_squared_error: 1.1700
# Epoch 24/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7059 - mean_squared_error: 0.9294 - val_loss: 0.7256 - val_mean_squared_error: 1.1677
# Epoch 25/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7044 - mean_squared_error: 0.9270 - val_loss: 0.7243 - val_mean_squared_error: 1.1656
# Epoch 26/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7031 - mean_squared_error: 0.9249 - val_loss: 0.7232 - val_mean_squared_error: 1.1638
# Epoch 27/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7019 - mean_squared_error: 0.9230 - val_loss: 0.7221 - val_mean_squared_error: 1.1621
# Epoch 28/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7009 - mean_squared_error: 0.9213 - val_loss: 0.7212 - val_mean_squared_error: 1.1607
# Epoch 29/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6999 - mean_squared_error: 0.9198 - val_loss: 0.7204 - val_mean_squared_error: 1.1594
# Epoch 30/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6991 - mean_squared_error: 0.9184 - val_loss: 0.7197 - val_mean_squared_error: 1.1583
# Epoch 31/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6984 - mean_squared_error: 0.9173 - val_loss: 0.7191 - val_mean_squared_error: 1.1572
# Epoch 32/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6977 - mean_squared_error: 0.9162 - val_loss: 0.7185 - val_mean_squared_error: 1.1563
# Epoch 33/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6971 - mean_squared_error: 0.9153 - val_loss: 0.7180 - val_mean_squared_error: 1.1555
# Epoch 34/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6966 - mean_squared_error: 0.9144 - val_loss: 0.7175 - val_mean_squared_error: 1.1548
# Epoch 35/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6961 - mean_squared_error: 0.9137 - val_loss: 0.7171 - val_mean_squared_error: 1.1541
# Epoch 36/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6957 - mean_squared_error: 0.9130 - val_loss: 0.7167 - val_mean_squared_error: 1.1536
# Epoch 37/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6954 - mean_squared_error: 0.9124 - val_loss: 0.7164 - val_mean_squared_error: 1.1531
# Epoch 38/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6950 - mean_squared_error: 0.9119 - val_loss: 0.7161 - val_mean_squared_error: 1.1526
# Epoch 39/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6947 - mean_squared_error: 0.9114 - val_loss: 0.7159 - val_mean_squared_error: 1.1522
# Epoch 40/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6945 - mean_squared_error: 0.9110 - val_loss: 0.7156 - val_mean_squared_error: 1.1518
# Epoch 41/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6942 - mean_squared_error: 0.9106 - val_loss: 0.7154 - val_mean_squared_error: 1.1515
# Epoch 42/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6940 - mean_squared_error: 0.9103 - val_loss: 0.7152 - val_mean_squared_error: 1.1512
# Epoch 43/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6938 - mean_squared_error: 0.9100 - val_loss: 0.7151 - val_mean_squared_error: 1.1509
# Epoch 44/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6936 - mean_squared_error: 0.9097 - val_loss: 0.7149 - val_mean_squared_error: 1.1507
# Epoch 45/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6935 - mean_squared_error: 0.9094 - val_loss: 0.7148 - val_mean_squared_error: 1.1505
# Epoch 46/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6934 - mean_squared_error: 0.9092 - val_loss: 0.7147 - val_mean_squared_error: 1.1503
# Epoch 47/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6932 - mean_squared_error: 0.9090 - val_loss: 0.7146 - val_mean_squared_error: 1.1501
# Epoch 48/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6931 - mean_squared_error: 0.9089 - val_loss: 0.7145 - val_mean_squared_error: 1.1500
# Epoch 49/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6930 - mean_squared_error: 0.9087 - val_loss: 0.7144 - val_mean_squared_error: 1.1499
# Epoch 50/150
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6929 - mean_squared_error: 0.9086 - val_loss: 0.7143 - val_mean_squared_error: 1.1497
# Epoch 51/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6929 - mean_squared_error: 0.9084 - val_loss: 0.7143 - val_mean_squared_error: 1.1496
# Epoch 52/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6928 - mean_squared_error: 0.9083 - val_loss: 0.7142 - val_mean_squared_error: 1.1495
# Epoch 53/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6927 - mean_squared_error: 0.9082 - val_loss: 0.7141 - val_mean_squared_error: 1.1495
# Epoch 54/150
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6927 - mean_squared_error: 0.9081 - val_loss: 0.7141 - val_mean_squared_error: 1.1494
# Epoch 55/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6926 - mean_squared_error: 0.9081 - val_loss: 0.7140 - val_mean_squared_error: 1.1493
# Epoch 56/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6926 - mean_squared_error: 0.9080 - val_loss: 0.7140 - val_mean_squared_error: 1.1492
# Epoch 57/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6925 - mean_squared_error: 0.9079 - val_loss: 0.7140 - val_mean_squared_error: 1.1492
# Epoch 58/150
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6925 - mean_squared_error: 0.9079 - val_loss: 0.7139 - val_mean_squared_error: 1.1491
# Epoch 59/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6925 - mean_squared_error: 0.9078 - val_loss: 0.7139 - val_mean_squared_error: 1.1491
# Epoch 60/150
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6924 - mean_squared_error: 0.9078 - val_loss: 0.7139 - val_mean_squared_error: 1.1491
# Epoch 61/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6924 - mean_squared_error: 0.9077 - val_loss: 0.7139 - val_mean_squared_error: 1.1490
# Epoch 62/150
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6924 - mean_squared_error: 0.9077 - val_loss: 0.7138 - val_mean_squared_error: 1.1490
# Epoch 63/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6924 - mean_squared_error: 0.9077 - val_loss: 0.7138 - val_mean_squared_error: 1.1490
# Epoch 64/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6923 - mean_squared_error: 0.9076 - val_loss: 0.7138 - val_mean_squared_error: 1.1489
# Epoch 65/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6923 - mean_squared_error: 0.9076 - val_loss: 0.7138 - val_mean_squared_error: 1.1489
# Epoch 66/150
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6923 - mean_squared_error: 0.9076 - val_loss: 0.7138 - val_mean_squared_error: 1.1489
# Epoch 67/150
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6923 - mean_squared_error: 0.9076 - val_loss: 0.7138 - val_mean_squared_error: 1.1489
# Epoch 68/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6923 - mean_squared_error: 0.9076 - val_loss: 0.7138 - val_mean_squared_error: 1.1489
# Epoch 69/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6923 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 70/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6923 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 71/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6923 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 72/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6923 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 73/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 74/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 75/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 76/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 77/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9075 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 78/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 79/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 80/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 81/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 82/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 83/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1488
# Epoch 84/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 85/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 86/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 87/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 88/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 89/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 90/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 91/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 92/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 93/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 94/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 95/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 96/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 97/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 98/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 99/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 100/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 101/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 102/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 103/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 104/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 105/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 106/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 107/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 108/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 109/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 110/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 111/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 112/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 113/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 114/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 115/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 116/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 117/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 118/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 119/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 120/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 121/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 122/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 123/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 124/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 125/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 126/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 127/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 128/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 129/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 130/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 131/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 132/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 133/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 134/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 135/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 136/150
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 137/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 138/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 139/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 140/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 141/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 142/150
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 143/150
# 27/27 [==============================] - 0s 9ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 144/150
# 27/27 [==============================] - 0s 15ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 145/150
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 146/150
# 27/27 [==============================] - 0s 12ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 147/150
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 148/150
# 27/27 [==============================] - 0s 11ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 149/150
# 27/27 [==============================] - 0s 10ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Epoch 150/150
# 27/27 [==============================] - 0s 14ms/step - loss: 0.6922 - mean_squared_error: 0.9074 - val_loss: 0.7137 - val_mean_squared_error: 1.1487
# Training MSE: 0.9073967933654785, Validation MSE: 1.1487300395965576
# [INFO]: Evaluando red neuronal...
# 16/16 [==============================] - 0s 4ms/step
# Error absoluto en test: 36.77196614390825
# error medio en test: 36.77196614390825

# %%
print('Datos train: ', X_train_image.shape)
print('Datos train:  ', y_train_reg.shape)
print('Datos val: ', X_val_image.shape)
print('Datos valt:  ', Y_val_reg.shape)
print('Datos test: ', X_test_image.shape)
print('Datos test:  ', y_test_reg.shape)
# Out:
# Datos train:  (2006, 224, 224, 3)
# Datos train:   (2006,)
# Datos val:  (301, 224, 224, 3)
# Datos valt:   (301,)
# Datos test:  (502, 224, 224, 3)
# Datos test:   (502,)

# %% [markdown]
# ### MODELO REGRESION DATOS IMAGENES

# %%
# Creo el modelo convolucional utilizando una red preentrenada en este caso VGG19 para regresion
# Despues de tener muchos problemas con la funcion de activacion de salida porque los rangos se salian de los valores de la funcion,
# utilice muchas funciones y ninguna me daba unos resultados validos para seguir con el trabajo. asi que despues de buscar , encontre la funcion lineal,
# que aunque esta en deshuso, fue la unico que me permitio seguir trabajando



# Cargar el modelo preentrenado
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Congelar las capas convolucionales modelo
for layer in base_model.layers:
  layer.trainable = False


# ponemos el tipo de modelo
model_IR = Sequential()


# Agregar capas
model_IR.add(base_model)
#model_IR.add(Dense(512, activation='relu'))
#model_IR.add(Dropout(0.5))
model_IR.add(Dense(512, activation='relu'))
model_IR.add(Flatten())
model_IR.add(Dense(1, activation='linear',name = "capa_sigmoide_imagenes"))

# Compilar el modelo

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=8,
    decay_rate=0.96,
    staircase=True
)

model_IR.compile(loss="mean_absolute_error", optimizer=Adam(learning_rate=lr_schedule),metrics=['mean_squared_error'])



# Entrenar el modelo
print("[INFO]: Entrenando el modelo...")

R=model_IR.fit(X_train_image1, y_train_reg1, validation_data=(X_val_image, Y_val_reg), epochs=10, batch_size=128)




# Evaluar el modelo
print("[INFO]: Evaluando red neuronal...")

mse_train = model_IR.evaluate(X_train_image1, y_train_reg1, verbose=0)[1]
mse_val = model_IR.evaluate(X_val_image, Y_val_reg, verbose=0)[1]
print(f'Training MSE: {mse_train}, Validation MSE: {mse_val}')



# calculo las predicciones y invierto el escalado
predictions_image_esc = model_IR.predict(X_test_image)
predictions_image = predictions_image_esc.reshape(-1, 1)
predictions_image = scaler.inverse_transform(predictions_image)

y_test_reg_img=y_test_reg.reshape(-1, 1)
y_test_reg_img = scaler.inverse_transform(y_test_reg_img)


test_error_image = mean_absolute_error(y_test_reg_img, predictions_image)


# Imprimir resultados

print(f'Error absoluto en test: {test_error_image}')


# Muestro gráfica de loss y MAE
plt.plot(R.history['loss'], label='Train Loss')
plt.plot(R.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()


print(f'error medio en test: {test_error_image}')
# Out:
# [INFO]: Entrenando el modelo...
# Epoch 1/10
# 14/14 [==============================] - 12s 777ms/step - loss: 2.2196 - mean_squared_error: 8.1055 - val_loss: 1.0194 - val_mean_squared_error: 2.2814
# Epoch 2/10
# 14/14 [==============================] - 11s 769ms/step - loss: 0.6994 - mean_squared_error: 1.0717 - val_loss: 0.6644 - val_mean_squared_error: 1.2044
# Epoch 3/10
# 14/14 [==============================] - 12s 857ms/step - loss: 0.5989 - mean_squared_error: 1.0070 - val_loss: 0.6333 - val_mean_squared_error: 1.2922
# Epoch 4/10
# 14/14 [==============================] - 11s 769ms/step - loss: 0.5687 - mean_squared_error: 0.9613 - val_loss: 0.6065 - val_mean_squared_error: 1.2254
# Epoch 5/10
# 14/14 [==============================] - 11s 783ms/step - loss: 0.5316 - mean_squared_error: 0.8995 - val_loss: 0.5699 - val_mean_squared_error: 1.1366
# Epoch 6/10
# 14/14 [==============================] - 12s 838ms/step - loss: 0.4971 - mean_squared_error: 0.8313 - val_loss: 0.5667 - val_mean_squared_error: 1.1059
# Epoch 7/10
# 14/14 [==============================] - 11s 816ms/step - loss: 0.4706 - mean_squared_error: 0.7955 - val_loss: 0.5648 - val_mean_squared_error: 1.1106
# Epoch 8/10
# 14/14 [==============================] - 11s 819ms/step - loss: 0.4488 - mean_squared_error: 0.7685 - val_loss: 0.5591 - val_mean_squared_error: 1.1002
# Epoch 9/10
# 14/14 [==============================] - 10s 748ms/step - loss: 0.4243 - mean_squared_error: 0.7397 - val_loss: 0.5591 - val_mean_squared_error: 1.1097
# Epoch 10/10
# 14/14 [==============================] - 11s 826ms/step - loss: 0.4049 - mean_squared_error: 0.7183 - val_loss: 0.5649 - val_mean_squared_error: 1.0824
# [INFO]: Evaluando red neuronal...
# Training MSE: 0.6695601940155029, Validation MSE: 1.082424521446228
# 16/16 [==============================] - 3s 159ms/step
# Error absoluto en test: 28.198131211725364
# error medio en test: 28.198131211725364

# %% [markdown]
# ### LATE_FUSION PARA REGRESION

# %%
# Saco las las predicciones de imagenes  para utilizar como input del modelo de fusion




# Escojo la capa flatten de mi red convolucional y creo un modelo para obtener las predicciones
capa_sigmoide_imagenes = model_IR.layers.index(model_IR.get_layer('capa_sigmoide_imagenes'))
feature_extractor_model = Model(inputs=model_IR.input, outputs=model_IR.layers[capa_sigmoide_imagenes].output)

# Obtenengo las predicciones  (antes de clasificacion )
input_imagenes = feature_extractor_model.predict(X_train_image)
input_imagenes_test = feature_extractor_model.predict(X_test_image)
# Out:
# 63/63 [==============================] - 10s 158ms/step
# 16/16 [==============================] - 3s 159ms/step

# %%
# Obtener la capa deseada del mi modelo fully conected
ultima_capa_tabular = model_tr.get_layer('capa_sigmoide_tabular')
model_t_predictions = Model(inputs=model_tr.input, outputs=ultima_capa_tabular.output)

# Obtengo las cprediciones de salida
caracteristicas_tabulares= model_t_predictions.predict(X_train)
caracteristicas_tabulares_test = model_t_predictions.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step

# %%
# Concatenar las predicciones tabulares con las predicciones de las imágenes
caracteristicas_entrada = np.concatenate((input_imagenes, caracteristicas_tabulares), axis=1)
caracteristicas_test = np.concatenate((input_imagenes_test, caracteristicas_tabulares_test), axis=1)

# %%
# Me aseguro que tengo el shape adecuado para que el modelo de fusion funcione correctamente


print( 'shape datos imagenes : ',input_imagenes.shape)
print( 'shape datos tabulares : ',caracteristicas_tabulares.shape)
print( 'shape union : ',caracteristicas_entrada.shape)
print( 'shape datos objetivo train : ',y_train_reg.shape)
print( 'shape datos imagenes test : ',input_imagenes_test.shape)
print( 'shape datos tabulares test : ',caracteristicas_tabulares_test.shape)
print( 'shape union : ',caracteristicas_test.shape)
print( 'shape datos objetivo test : ',y_test.shape)
# Out:
# shape datos imagenes :  (2006, 1)
# shape datos tabulares :  (2006, 1)
# shape union :  (2006, 2)
# shape datos objetivo train :  (2006,)
# shape datos imagenes test :  (502, 1)
# shape datos tabulares test :  (502, 1)
# shape union :  (502, 2)
# shape datos objetivo test :  (502,)

# %%
# Dividimos los datos para hacer el ultimp modelo ( fusion )
X_train_fusion, X_val_fusion, y_train_fusion, y_val_fusion = train_test_split(caracteristicas_entrada, y_train_reg, test_size=0.15, random_state=42)

# %%
# Creo el modelo final

model_fusion = Sequential()
model_fusion.add(Dense(1024, activation='relu', input_dim=caracteristicas_entrada.shape[1]))
model_fusion.add(Dropout(0.5))

model_fusion.add(Dense(1, activation='linear'))

# Compilo el modelo final
lr_schedulef = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=8,
    decay_rate=0.96,
    staircase=True
)

model_fusion.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=lr_schedulef), metrics=['mean_absolute_error'])

# Entreno el modelo final
F=model_fusion.fit(X_train_fusion, y_train_fusion,
                 batch_size=64,
                 shuffle=True,
                 epochs=10,
                 validation_data=(X_val_fusion, y_val_fusion))

# Evaluo el modelo final

mse_train1 = model_fusion.evaluate(X_train_fusion, y_train_fusion, verbose=0)[1]
mse_val1 = model_fusion.evaluate(X_val_fusion, y_val_fusion, verbose=0)[1]
print(f'Training MSE: {mse_train1}, Validation MSE: {mse_val1}')



# calculo las predicciones y invierto el escalado
predictions_fusion_esc = model_fusion.predict(caracteristicas_test)
predictions_fusion = predictions_fusion_esc.reshape(-1, 1)
predictions_fusion = scaler.inverse_transform(predictions_fusion)

y_test_reg_fusion=y_test_reg.reshape(-1, 1)
y_test_reg_fusion = scaler.inverse_transform(y_test_reg_fusion)


test_error_fusion = mean_absolute_error(y_test_reg_fusion, predictions_fusion)


# Imprimir resultados

print(f'Error absoluto en test: {test_error_fusion}')


# Muestro gráfica de loss y MAE
plt.plot(F.history['loss'], label='Train Loss')
plt.plot(F.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()


print(f'error medio en test: {test_error_fusion}')
# Out:
# Epoch 1/10
# 27/27 [==============================] - 2s 15ms/step - loss: 0.7197 - mean_absolute_error: 0.4846 - val_loss: 1.0070 - val_mean_absolute_error: 0.5445
# Epoch 2/10
# 27/27 [==============================] - 0s 7ms/step - loss: 0.5964 - mean_absolute_error: 0.4041 - val_loss: 0.9769 - val_mean_absolute_error: 0.5364
# Epoch 3/10
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5741 - mean_absolute_error: 0.3952 - val_loss: 0.9472 - val_mean_absolute_error: 0.5182
# Epoch 4/10
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5628 - mean_absolute_error: 0.3869 - val_loss: 0.9293 - val_mean_absolute_error: 0.5025
# Epoch 5/10
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5526 - mean_absolute_error: 0.3744 - val_loss: 0.9077 - val_mean_absolute_error: 0.5059
# Epoch 6/10
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5466 - mean_absolute_error: 0.3833 - val_loss: 0.8989 - val_mean_absolute_error: 0.4858
# Epoch 7/10
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5362 - mean_absolute_error: 0.3801 - val_loss: 0.8868 - val_mean_absolute_error: 0.4837
# Epoch 8/10
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5377 - mean_absolute_error: 0.3761 - val_loss: 0.8781 - val_mean_absolute_error: 0.4784
# Epoch 9/10
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5233 - mean_absolute_error: 0.3696 - val_loss: 0.8715 - val_mean_absolute_error: 0.4758
# Epoch 10/10
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5241 - mean_absolute_error: 0.3750 - val_loss: 0.8675 - val_mean_absolute_error: 0.4697
# Training MSE: 0.36864912509918213, Validation MSE: 0.469664603471756
# 16/16 [==============================] - 0s 2ms/step
# Error absoluto en test: 24.675334750893583
# error medio en test: 24.675334750893583
